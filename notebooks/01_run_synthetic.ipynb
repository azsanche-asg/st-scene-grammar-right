# %% [markdown]
# # ST-SceneGrammar — Synthetic Demo

# %% [markdown]
# Run a synthetic experiment end-to-end.

# %%
# --- SETUP CELL: clone repo and install dependencies ---
import os

# Clone or update your repository
REPO_URL = "https://github.com/azsanche-asg/st-scene-grammar-right.git"
if not os.path.exists("st-scene-grammar-right"):
    # !git clone $REPO_URL
else:
    # %cd st-scene-grammar-right
    # !git pull
    # %cd ..

# Move into repo
# %cd st-scene-grammar-right

# Install dependencies (skip MiDaS if needed)
# !grep -v "MiDaS" requirements.txt > req_tmp.txt
# !pip install -r req_tmp.txt

# Optional: verify setup
# !pytest -q tests/test_basic.py || echo "Tests failed or not found — continuing anyway"
# Out:
# Cloning into 'st-scene-grammar-right'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 49 (delta 7), reused 42 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 9.61 KiB | 1.20 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/st-scene-grammar-right
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 90.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 94.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from st_scene_grammar.utils.config import load_config
from st_scene_grammar.eval.runner import run_experiment
cfg = load_config('st_scene_grammar/configs/synthetic_demo.yaml')
res = run_experiment(cfg, cfg['save']['out_dir'])
res

# %% [markdown]
# Edit `st_scene_grammar/configs/synthetic_demo.yaml` to tweak modules and ablations.
